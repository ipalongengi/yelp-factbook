# %%
sc

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]
#colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
explode = (0.05,0.05,0.05,0.05)
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', pctdistance=0.85,startangle=90,explode=explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
VegasHigh = [('"Mon Ami Gabi"', 6710), ('"Bacchanal Buffet"', 5723), ('"Wicked Spoon"', 4909), ('"Gordon Ramsay BurGR"', 4655), ('"Earl of Sandwich"', 4620), ('"Hash House A Go Go"', 4094), ('"Lotus of Siam"', 3621), ('"Secret Pizza"', 3480), ('"The Buffet"', 3244), ('"Bouchon at the Venezia Tower"', 3139)]

# %%
VegasHighName = list(map(lambda x: x[0],VegasHigh)) #labels
VegasHighNum = list(map(lambda x: x[1],VegasHigh)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = VegasHighName
sizes = VegasHighNum
total = sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=90,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Las Vegas", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"High Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Vegas10HIGH.png",dp1=100,bbox_inches="tight")

# %%
VegasLow = [('"Luxor Hotel and Casino Las Vegas"', 1703), ('"Flamingo Las Vegas Hotel & Casino"', 1562), ('"Circus Circus Las Vegas Hotel and Casino"', 1290), ('"Serendipity 3"', 1284), ('"Bacchanal Buffet"', 1283), ('"MGM Grand Hotel"', 1254), ('"Excalibur Hotel"', 1194), ('"Monte Carlo Hotel And Casino"', 1133), ('"Wicked Spoon"', 1042), ('"Rio All Suites Hotel & Casino"', 964)]
VegasLowName = list(map(lambda x: x[0],VegasLow)) #labels
VegasLowNum = list(map(lambda x: x[1],VegasLow)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = VegasLowName
sizes = VegasLowNum
total = sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=270,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Las Vegas", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"Low Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Vegas10LOW.png",dp1=100,bbox_inches="tight")

# %%
EdinburghHigh = [('"Edinburgh Castle"', 359), ('"The Devil\'s Advocate"', 254), ('"Oink"', 226), ('"The Edinburgh Larder"', 175), ('"Arthur\'s Seat"', 170), ('"The Outsider"', 168), ('"National Museum of Scotland"', 157), ('"Mums"', 152), ('"The Dogs"', 146), ('"The Elephant House"', 146)]
EdinburghHighName = list(map(lambda x: x[0],EdinburghHigh)) #labels
EdinburghHighNum = list(map(lambda x: x[1],EdinburghHigh)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = EdinburghHighName
sizes = EdinburghHighNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=90,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Edinburgh", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"High Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Edinburgh10HIGH.png",dp1=100,bbox_inches="tight")

# %%
EdinburghLow =[('"The Elephant House"', 56), ('"The Witchery By The Castle"', 35), ('"Espionage"', 25), ('"The Filling Station"', 24), ('"Frankenstein & Bier Keller"', 23), ('"The Standing Order"', 21), ('"The Dogs"', 20), ('"Ghillie Dhu"', 19), ('"Deacon Brodies Tavern"', 19), ('"Edinburgh Castle"', 19)]
EdinburghLowName = list(map(lambda x: x[0],EdinburghLow)) #labels
EdinburghLowNum = list(map(lambda x: x[1],EdinburghLow)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = EdinburghLowName
sizes = EdinburghLowNum
total = sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=270,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Edinburgh", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"Low Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Edinburgh10LOW.png",dp1=100,bbox_inches="tight")

# %%
StuttgartHigh =[('"Mercedes-Benz-Museum"', 157), ('"Wilhelma Zoologisch-Botanischer Garten"', 151), ('"Flughafen Stuttgart"', 144), ('"Ochs\'n Willi"', 108), ('"Il Pomodoro"', 106), ('"Markthalle Stuttgart"', 104), ('"Block House"', 102), ('"Ftengold"', 98), ('"Vapiano"', 98), ('"QQ Sushi Lounge"', 95)]
StuttgartHighName = list(map(lambda x: x[0],StuttgartHigh)) #labels
StuttgartHighNum = list(map(lambda x: x[1],StuttgartHigh)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = StuttgartHighName
sizes = StuttgartHighNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=90,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Stuttgart", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"High Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Stuttgart10HIGH.png",dp1=100,bbox_inches="tight")

# %%
StuttgartLow =[('"Woody''s"', 40), ('"Restaurant Hacienda"', 37), ('"Vapiano"', 36), ('"Stlerbund"', 34), ('"Brauhaus Calwer-Eck"', 34), ('"Tialini"', 33), ('"McDonald\'s"', 30), ('"Sophies Brauhaus"', 29), ('"Besitos"', 28), ('"Cafe Kostbar"', 28)]
StuttgartLowName = list(map(lambda x: x[0],StuttgartLow)) #labels
StuttgartLowNum = list(map(lambda x: x[1],StuttgartLow)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = StuttgartLowName
sizes = StuttgartLowNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=270,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Stuttgart", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"Low Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Stuttgart10LOW.png",dp1=100,bbox_inches="tight")

# %%
TorontoHigh = [('"Pai Northern Thai Kitchen"', 1418), ('"Khao San Road"', 1134), ('"KINKA IZAKAYA ORIGINAL"', 1101), ('"Banh Mi Boys"', 930), ('"Seven Lives Tacos Y Mariscos"', 911), ('"Uncle Tetsu\'s Japanese Cheesecake"', 708), ('"Bang Bang Ice Cream and bakery"', 698), ('"Sansotei Ramen"', 657), ('"Salad King Restaurant"', 654), ('"Insomnia Restaurant & Lounge"', 631)]
TorontoHighName = list(map(lambda x: x[0],TorontoHigh)) #labels
TorontoHighNum = list(map(lambda x: x[1],TorontoHigh)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = TorontoHighName
sizes = TorontoHighNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=90,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Toronto", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"High Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Toronto10HIGH.png",dp1=100,bbox_inches="tight")

# %%
TorontoLow = [('"Momofuku Noodle Bar"', 239), ('"El Catrin Destileria"', 171), ('"Sweet Jesus"', 155), ('"Salad King Restaurant"', 153), ('"Uncle Tetsu\'s Japanese Cheesecake"', 140), ('"Khao San Road"', 137), ('"Toula Restaurant & Bar"', 130), ('"Rol San"', 127), ('"360 Restaurant"', 124), ('"Japango"', 124)]
TorontoLowName = list(map(lambda x: x[0],TorontoLow)) #labels
TorontoLowNum = list(map(lambda x: x[1],TorontoLow)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = TorontoLowName
sizes = TorontoLowNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=270,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Toronto", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"Low Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Toronto10LOW.png",dp1=100,bbox_inches="tight")

# %%
CharlotteHigh = [('"Charlotte Douglas International Airport"', 1279), ('"The Cowfish Sushi Burger Bar"', 1254), ('"French Bakery"', 1188), ('"Midwood Smokehouse"', 1119), ('"Tupelo Honey"', 876), ('"Cabo Fish Taco"', 798), ('"Soul Gastrolounge"', 746), ('"Pinkys Westside Grill"', 730), ('"Viva Chicken"', 729), ('"Futo Buta"', 638)]
CharlotteHighName = list(map(lambda x: x[0],CharlotteHigh)) #labels
CharlotteHighNum = list(map(lambda x: x[1],CharlotteHigh)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = CharlotteHighName
sizes = CharlotteHighNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=90,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Charlotte", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"High Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Charlotte10HIGH.png",dp1=100,bbox_inches="tight")

# %%
CharlotteLow = [('"Charlotte Douglas International Airport"', 305), ('"American Airlines"', 223), ('"Tequileria"', 222), ('"Tupelo Honey"', 177), ('"Fahrenheit"', 174), ('"Studio Movie Grill"', 174), ('"Hot Taco"', 160), ('"The Peculiar Rabbit"', 158), ('"Merts Heart & Soul"', 153), ('"Cabo Fish Taco"', 147)]
CharlotteLowName = list(map(lambda x: x[0],CharlotteLow)) #labels
CharlotteLowNum = list(map(lambda x: x[1],CharlotteLow)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = CharlotteLowName
sizes = CharlotteLowNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=270,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Charlotte", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"Low Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Charlotte10LOW.png",dp1=100,bbox_inches="tight")

# %%
PhoenixHigh = [('"Bobby Q"', 1837), ('"Pizzeria Bianco"', 1710), ('"Phoenix Sky Harbor International Airport"', 1660), ('"Lux Central"', 1655), ('"Cibo"', 1569), ('"La Santisima"', 1533), ('"Little Miss BBQ"', 1435), ('"Matts Big Breakfast"', 1332), ('"The Arrogant Butcher"', 1319), ('"Lo-Los Chicken & Waffles"', 1266)]

PhoenixHighName = list(map(lambda x: x[0],PhoenixHigh)) #labels
PhoenixHighNum = list(map(lambda x: x[1],PhoenixHigh)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = PhoenixHighName
sizes = PhoenixHighNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=90,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Phoenix", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"High Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Phoenix10HIGH.png",dp1=100,bbox_inches="tight")

# %%
PhoenixLow = [('"Cox Communications"', 618), ('"Phoenix Sky Harbor International Airport"', 555), ('"US Airways"', 402), ('"OnTrac"', 356), ('"Hertz Rent A Car"', 327), ('"Pizzeria Bianco"', 326), ('"Payless Car Rental"', 315), ('"American Airlines"', 309), ('"Rustlers Rooste"', 303), ('"Fox Rent A Car"', 264)]
PhoenixLowName = list(map(lambda x: x[0],PhoenixLow)) #labels
PhoenixLowNum = list(map(lambda x: x[1],PhoenixLow)) #numerical vals

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = PhoenixLowName
sizes = PhoenixLowNum
total =sum(sizes)
#colors
colors = ['#ffe119','#3cb44b','#008080','#f58231','#911eb4','#e6194b',"#FF570C","#6A9C78","#C06C84","#65DAF7"]
 
fig1, ax1 = plt.subplots(figsize=(7,7))
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct=lambda(p): '{:.0f}'.format(p * total / 100), pctdistance=0.85,startangle=270,explode=explode)
#draw circle
for text,autotext in zip(texts,autotexts):
    text.set_fontsize(14)
    autotext.set_fontsize(14)

centre_circle = plt.Circle((0,0),0.70,fc='white')

#plt.title('Top 40 Business Categories sdsdOverall', y=1.08,fontsize=22)
plt.text(-0.3, 0.15,"Phoenix", fontsize=25)
plt.text(-0.55, 0,"Top 10 Businesses", fontsize=25)
plt.text(-0.35, -0.15,"Low Ratings", fontsize=25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()


fig1 = plt.gcf()
plt.tight_layout()
plt.show()
plt.draw()
fig1.savefig("Phoenix10LOW.png",dp1=100,bbox_inches="tight")
